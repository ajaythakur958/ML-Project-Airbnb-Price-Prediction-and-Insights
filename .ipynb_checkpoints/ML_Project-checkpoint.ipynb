# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# # import csv data file into pandas dataframe for processing the data cleaning

# %%
df = pd.read_csv("airbnb_data.csv")

# %%
df.head(1)
# Out:
#         id  log_price property_type        room_type  \
# 0  6901257   5.010635     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude  longitude  \
# 0  Real Bed              strict          True  ...  40.696524 -73.991617
#
#                              name     neighbourhood number_of_reviews  \
# 0  Beautiful brownstone 1-bedroom  Brooklyn Heights                 2
#
#   review_scores_rating                                      thumbnail_url  \
# 0                100.0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...
#
#   zipcode bedrooms  beds
# 0   11201      1.0   1.0
#
# [1 rows x 29 columns]

# %%
print("Shape of Matrix:", df.shape)
print('--'*50)
print(df.columns)
# Out:
# Shape of Matrix: (74111, 29)
# ----------------------------------------------------------------------------------------------------
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %% [markdown]
# # Removing useless columns that is useless for linear regression

# %%
cols_to_drop = ['id','name','thumbnail_url','description']
df = df.drop(columns=cols_to_drop)
df.head(1)
# Out:
#    log_price property_type        room_type  \
# 0   5.010635     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
#
#    bed_type cancellation_policy  cleaning_fee city  ... instant_bookable  \
# 0  Real Bed              strict          True  NYC  ...                f
#
#   last_review   latitude  longitude     neighbourhood number_of_reviews  \
# 0  18-07-2016  40.696524 -73.991617  Brooklyn Heights                 2
#
#   review_scores_rating  zipcode  bedrooms beds
# 0                100.0    11201       1.0  1.0
#
# [1 rows x 25 columns]

# %% [markdown]
# # Removing useless special characters from amenities column and couting the amenties_counts

# %%
df['amenities'] = df['amenities'].apply(lambda x: x.replace("{","").replace("}","").replace('"','').split(","))
df['amenities'] = df['amenities'].apply(lambda x: [a.strip() for a in x if "translation missing" not in a])
df['amenities_count'] = df['amenities'].apply(len)
df.drop(columns=['amenities'], inplace=True)

# %% [markdown]
# # Checking nulls

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# host_response_rate        18299
# review_scores_rating      16722
# first_review              15864
# last_review               15827
# neighbourhood              6872
# zipcode                     968
# bathrooms                   200
# host_has_profile_pic        188
# host_identity_verified      188
# host_since                  188
# beds                        131
# bedrooms                     91
# bed_type                      0
# accommodates                  0
# room_type                     0
# property_type                 0
# log_price                     0
# city                          0
# cleaning_fee                  0
# cancellation_policy           0
# instant_bookable              0
# latitude                      0
# longitude                     0
# number_of_reviews             0
# amenities_count               0
# dtype: int64

# %% [markdown]
# # Checking types of unique values in columns having null values

# %%
numeric_cols = ['host_response_rate','review_scores_rating','first_review','last_review', 'bathrooms',
                'host_identity_verified','host_since','host_has_profile_pic','beds','bedrooms','zipcode']

for col in numeric_cols:
    print(f"{col} | Type: {df[col].dtype} | Nulls: {df[col].isnull().sum()} | Filled: {df[col].notnull().sum()}")
    print("Unique Values:", df[col].unique())
    print("-" * 80)
# Out:
# host_response_rate | Type: object | Nulls: 18299 | Filled: 55812
# Unique Values: [nan '100%' '71%' '68%' '67%' '83%' '50%' '90%' '86%' '92%' '82%' '80%'
#  '89%' '93%' '99%' '0%' '88%' '96%' '70%' '94%' '91%' '25%' '95%' '98%'
#  '62%' '29%' '33%' '81%' '63%' '38%' '60%' '79%' '78%' '75%' '65%' '97%'
#  '87%' '40%' '54%' '53%' '58%' '76%' '30%' '64%' '17%' '20%' '77%' '73%'
#  '41%' '59%' '57%' '85%' '56%' '42%' '44%' '35%' '14%' '74%' '27%' '10%'
#  '84%' '6%' '72%' '36%' '55%' '43%' '13%' '39%' '46%' '26%' '61%' '52%'
#  '23%' '22%' '69%' '66%' '15%' '11%' '31%' '21%' '47%']
# --------------------------------------------------------------------------------
# review_scores_rating | Type: float64 | Nulls: 16722 | Filled: 57389
# Unique Values: [100.  93.  92.  nan  40.  97.  99.  90.  89.  91.  88.  86.  72.  98.
#   95.  96.  84.  80.  94.  87.  85.  70.  60.  75.  20.  76.  83.  82.
#   78.  73.  55.  81.  67.  71.  77.  79.  47.  74.  68.  66.  63.  50.
#   53.  65.  64.  27.  69.  30.  58.  35.  62.  49.  57.  54.  56.]
# --------------------------------------------------------------------------------
# first_review | Type: object | Nulls: 15864 | Filled: 58247
# Unique Values: ['18-06-2016' '05-08-2017' '30-04-2017' ... '23-10-2012' '07-06-2011'
#  '01-12-2010']
# --------------------------------------------------------------------------------
# last_review | Type: object | Nulls: 15827 | Filled: 58284
# Unique Values: ['18-07-2016' '23-09-2017' '14-09-2017' ... '10-06-2014' '06-05-2014'
#  '28-12-2013']
# --------------------------------------------------------------------------------
# bathrooms | Type: float64 | Nulls: 200 | Filled: 73911
# Unique Values: [1.  1.5 2.  nan 2.5 3.  0.5 4.5 5.  0.  4.  3.5 5.5 7.5 6.  8.  7.  6.5]
# --------------------------------------------------------------------------------
# host_identity_verified | Type: object | Nulls: 188 | Filled: 73923
# Unique Values: ['t' 'f' nan]
# --------------------------------------------------------------------------------
# host_since | Type: object | Nulls: 188 | Filled: 73923
# Unique Values: ['26-03-2012' '19-06-2017' '25-10-2016' ... '03-03-2008' '30-04-2010'
#  '23-08-2009']
# --------------------------------------------------------------------------------
# host_has_profile_pic | Type: object | Nulls: 188 | Filled: 73923
# Unique Values: ['t' nan 'f']
# --------------------------------------------------------------------------------
# beds | Type: float64 | Nulls: 131 | Filled: 73980
# Unique Values: [ 1.  3.  2.  7.  4.  6.  5. nan 10.  8. 16.  9. 13. 12. 11. 14. 15.  0.
#  18.]
# --------------------------------------------------------------------------------
# bedrooms | Type: float64 | Nulls: 91 | Filled: 74020
# Unique Values: [ 1.  3.  2.  0.  4. nan  5.  6.  7.  8.  9. 10.]
# --------------------------------------------------------------------------------
# zipcode | Type: object | Nulls: 968 | Filled: 73143
# Unique Values: ['11201' '10019' '10027' '94117' '20009' '94131' '90292' '90015' '94121'
#  '91748' '10009' '90254' '90277' '90804' '60622' '2127' '10002' '11226'
#  '91401' '11212' '11411' nan '11374' '90028' '10016' '11225' '90036'
#  '90291' '90046' '90026' '94118' '11211' '10003' '60605' '90068' '90057'
#  '10021' '20037' '11237' '11233' '60608' '10001' '94127' '91403' '11249'
#  '10037' '10011' '10032' '91106' '94107' '20018' '90027' '91601' '20001'
#  '10022' '91201' '90013' '11217' '91016' '10031' '10014' '11101' '94110'
#  '94134' '91501' '10029' '90230' '90039' '11221' '20019' '60647' '20020'
#  '10025' '10013' '10040' '91604' '10039' '10038' '60614' '20002' '11219'
#  '11222' '90042' '94114' '20008' '11238' '20007' '11206' '91208' '11223'
#  '2130' '2114' '94103' '91107' '11355' '11220' '91406' '10036' '10024'
#  '90004' '10012' '10044' '10023' '10028' '20012' '91205' '2132' '60611'
#  '60609' '91506' '90044' '2139' '90280' '94111' '90638' '90063' '91773'
#  '11432' '11358' '91024' '90710' '90602' '60623' '91103' '90059' '90262'
#  '91744' '60619' '91303' '91355' '91402' '90095' '20064' '10280' '90274'
#  '90706' '10472' '91723' '90755' '60629' '91020' '91207' '93543' '91792'
#  '10281' '10312' '91390' '60302'
#  '95202\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n94158' '90805' '10454' '20816'
#  '60632' '93535' '60651' '2445' '10458' '91768' '10119' '90603' '20748'
#  '2143' '91731' '91436' '10069' '10048' '90304' '60628' '90061' '94130'
#  '10467' '90604' '91342' '11420' '90650' '90601' '90023' '93536' '11427'
#  '91204' '60636' '94104' '91108' '11580' '91706' '20782' '91387' '91362'
#  '60638' '90744' '91740' '90242' '90640' '90201' '2163' '20052' '93534'
#  '90003' '93563' '11694' '92397' '91340' '60631' '60620' '10129' '91308'
#  '90255' '90716' '20268' '2446' '91722' '60656' '90605' '92614' '10303'
#  '91523' '90670' '91351' '93532' '90715' '11103-3233' '60643' '10106'
#  '10302' '90040' '20815' '10000' '94129' '11385-2308' '93552' '10118'
#  '90022' '90701' '90241' '11366' '60652' '11004' '90840' '91345' '10550'
#  '15074' '20781' '91606-1412' '20910' '90067' '11249\n\n\n\n\n\n11249'
#  '10308' '90240' '11426-1175' '11357' '10270' '90221' '90002' '90606'
#  '11423' '11362' '92880' '91001-2243' '91764' '60617' 'Near 91304' '93105'
#  '90071' '20229' '10307' '10002-2289' '92821' '90039-2715' '90630' '11363'
#  '210' '20001-4044' '20372' '90222' '60633' '7302' '20912' '60805' '91786'
#  '10279' '2138' '10704' '91802' '90403-2638' '91377' '1m' '91708'
#  '90034-2203' '90035-4475' '11509' '11001' '60660-1448' '90036-2514'
#  '60603' '94401' '2186' '10162' '2458' '2472' '10309' '9004' '11239']
# --------------------------------------------------------------------------------

# %% [markdown]
# # Handling null values

# %% [markdown]
# ### Replacing string(num%) host_response_rate column to numeric num and replace null value with median

# %%
# Function to replace '%' to none and empty values replace by nan
def convert_percent(x):
    try:
        return float(str(x).replace('%',''))
    except:
        return np.nan
df['host_response_rate'] = df['host_response_rate'].apply(convert_percent)

#Calculate and Replace mull values with median
median_response = df['host_response_rate'].median()
df['host_response_rate'] = df['host_response_rate'].fillna(median_response)

# %% [markdown]
# ### Numeric columns fills missing with median
# ### median because it's robust to outliers

# %%
numeric_cols = ['bathrooms', 'review_scores_rating', 'bedrooms', 'beds']
for col in numeric_cols:
    median_value = df[col].median()
    df[col] = df[col].fillna(median_value)

# %% [markdown]
# ### Converting bool categorical data to 0/1 and replace null with mode

# %%
# Convert t/f to 1/0 and 
df['host_has_profile_pic'] = df['host_has_profile_pic'].map({'t':1,'f':0})
df['host_identity_verified'] = df['host_identity_verified'].map({'t':1,'f':0})
# Replaces with mode
df['host_has_profile_pic'] = df['host_has_profile_pic'].fillna(df['host_has_profile_pic'].mode()[0])
df['host_identity_verified'] = df['host_identity_verified'].fillna(df['host_identity_verified'].mode()[0])

# %% [markdown]
# # Replace null with unknown in Text column for neigbours

# %%
df['neighbourhood'] = df['neighbourhood'].fillna('Unknown').str.strip()

# %% [markdown]
# # Feature Engineering for date columns: converting to number of days since today

# %%
# Converts Date columns from object to datetime DataType
df['first_review'] = pd.to_datetime(df['first_review'], dayfirst=True, errors='coerce')
df['last_review'] = pd.to_datetime(df['last_review'], dayfirst=True, errors='coerce')
df['host_since'] = pd.to_datetime(df['host_since'], dayfirst=True, errors='coerce')

# Fill missing date values with median 
df['first_review'] = df['first_review'].fillna(df['first_review'].median())
df['last_review'] = df['last_review'].fillna(df['last_review'].median())
df['host_since'] = df['host_since'].fillna(df['host_since'].median())

today = pd.Timestamp('today')

# Convert date columns into numeric features
df['host_days_since'] = (today - df['host_since']).dt.days
df['days_since_first_review'] = (today - df['first_review']).dt.days
df['days_since_last_review'] = (today - df['last_review']).dt.days

# Dropping the original date columns
df.drop(['first_review', 'last_review', 'host_since'], axis=1, inplace=True)

# %% [markdown]
# # Using regex we identify valid zipcode contains 4 or 5 num and remove extra string values from it

# %%
import re

def clean_zipcode(x):
    x = str(x).strip()
    x = re.sub(r'\s+', '', x)
    match = re.findall(r'\d{4,5}', x)
    if match:
        return match[0]
    else:
        return 0  # replace invalid with 0

df['zipcode'] = df['zipcode'].apply(clean_zipcode).astype(int)

# %%
# Fill missing date values with mode in zipcode 
df['zipcode'] = df['zipcode'].fillna(df['zipcode'].mode()[0])
print(df['zipcode'].nunique())
# Out:
# 650

# %%
df.isnull().sum()
# Out:
# log_price                  0
# property_type              0
# room_type                  0
# accommodates               0
# bathrooms                  0
# bed_type                   0
# cancellation_policy        0
# cleaning_fee               0
# city                       0
# host_has_profile_pic       0
# host_identity_verified     0
# host_response_rate         0
# instant_bookable           0
# latitude                   0
# longitude                  0
# neighbourhood              0
# number_of_reviews          0
# review_scores_rating       0
# zipcode                    0
# bedrooms                   0
# beds                       0
# amenities_count            0
# host_days_since            0
# days_since_first_review    0
# days_since_last_review     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   log_price                74111 non-null  float64
#  1   property_type            74111 non-null  object
#  2   room_type                74111 non-null  object
#  3   accommodates             74111 non-null  int64
#  4   bathrooms                74111 non-null  float64
#  5   bed_type                 74111 non-null  object
#  6   cancellation_policy      74111 non-null  object
#  7   cleaning_fee             74111 non-null  bool
#  8   city                     74111 non-null  object
#  9   host_has_profile_pic     74111 non-null  float64
#  10  host_identity_verified   74111 non-null  float64
#  11  host_response_rate       74111 non-null  float64
#  12  instant_bookable         74111 non-null  object
#  13  latitude                 74111 non-null  float64
#  14  longitude                74111 non-null  float64
#  15  neighbourhood            74111 non-null  object
#  16  number_of_reviews        74111 non-null  int64
#  17  review_scores_rating     74111 non-null  float64
#  18  zipcode                  74111 non-null  int64
#  19  bedrooms                 74111 non-null  float64
#  20  beds                     74111 non-null  float64
#  21  amenities_count          74111 non-null  int64
#  22  host_days_since          74111 non-null  int64
#  23  days_since_first_review  74111 non-null  int64
#  24  days_since_last_review   74111 non-null  int64
# dtypes: bool(1), float64(10), int64(7), object(7)
# memory usage: 13.6+ MB

# %% [markdown]
# # Select Only numeric Columns for outliers detection

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

print(numeric_cols)
# Out:
# Index(['log_price', 'accommodates', 'bathrooms', 'host_has_profile_pic',
#        'host_identity_verified', 'host_response_rate', 'latitude', 'longitude',
#        'number_of_reviews', 'review_scores_rating', 'zipcode', 'bedrooms',
#        'beds', 'amenities_count', 'host_days_since', 'days_since_first_review',
#        'days_since_last_review'],
#       dtype='object')

# %% [markdown]
# ## Outliers detection for numeric columns

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_cols:
    Q1 = np.percentile(df[col], 25)
    Q3 = np.percentile(df[col], 75)
    IQR = Q3 - Q1
    
    outliers = df[(df[col] < Q1 - 1.5*IQR) | (df[col] > Q3 + 1.5*IQR)][col]
    
    percent_outliers = (len(outliers) / len(df[col])) * 100
    
    print(f"{col:<25} : {percent_outliers:6.2f}% outliers")
# Out:
# log_price                 :   2.07% outliers
# accommodates              :   4.86% outliers
# bathrooms                 :  21.34% outliers
# host_has_profile_pic      :   0.30% outliers
# host_identity_verified    :   0.00% outliers
# host_response_rate        :  16.94% outliers
# latitude                  :   0.00% outliers
# longitude                 :   0.00% outliers
# number_of_reviews         :  11.07% outliers
# review_scores_rating      :   6.24% outliers
# zipcode                   :   0.00% outliers
# bedrooms                  :  32.70% outliers
# beds                      :   7.67% outliers
# amenities_count           :   1.84% outliers
# host_days_since           :   0.25% outliers
# days_since_first_review   :   7.40% outliers
# days_since_last_review    :  10.84% outliers

# %% [markdown]
# # Beds, Bathrooms, and Bedrooms have the most outliers, so we’ll cap their extreme values at 1% to preserve 99% of the real data.

# %%
# prints unique values and types of the columns
cols = ['bedrooms', 'beds', 'bathrooms']
for col in cols:
    print(f"{col} | Type: {df[col].dtype} | Nulls: {df[col].isnull().sum()} | Filled: {df[col].notnull().sum()} | Unique Count: {df[col].nunique()}")
    print("Unique Values:", df[col].unique()[:100])
    print('--'*50)
# Out:
# bedrooms | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 11
# Unique Values: [ 1.  3.  2.  0.  4.  5.  6.  7.  8.  9. 10.]
# ----------------------------------------------------------------------------------------------------
# beds | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 18
# Unique Values: [ 1.  3.  2.  7.  4.  6.  5. 10.  8. 16.  9. 13. 12. 11. 14. 15.  0. 18.]
# ----------------------------------------------------------------------------------------------------
# bathrooms | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 17
# Unique Values: [1.  1.5 2.  2.5 3.  0.5 4.5 5.  0.  4.  3.5 5.5 7.5 6.  8.  7.  6.5]
# ----------------------------------------------------------------------------------------------------

# %%
cols = ['bedrooms', 'beds', 'bathrooms']
for col in cols:
    upper_limit = df[col].quantile(0.99)
    print(f"99th Percentile (Upper Limit) of {col}:", upper_limit)
    df[col] = np.where(df[col] > upper_limit, upper_limit, df[col])

# Converts these two columns to int since it doesn't have any float values
df['bedrooms'] = df['bedrooms'].astype(int)
df['beds'] = df['beds'].astype(int)
# Out:
# 99th Percentile (Upper Limit) of bedrooms: 4.0
# 99th Percentile (Upper Limit) of beds: 6.0
# 99th Percentile (Upper Limit) of bathrooms: 3.5

# %% [markdown]
# ## Distribution and BoxPlot after cap to 1% for cols 'bedrooms', 'beds', 'bathrooms'

# %%
cols = ['bedrooms', 'beds', 'bathrooms']
for col in cols:
    print(f"Column '{col}' unique values:", df[col].unique()[:50])
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.histplot(df[col], kde=True, bins=30, color='skyblue', edgecolor='black')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    
    plt.tight_layout()
    plt.show()
# Out:
# Column 'bedrooms' unique values: [1 3 2 0 4]
# Column 'beds' unique values: [1 3 2 6 4 5 0]
# Column 'bathrooms' unique values: [1.  1.5 2.  2.5 3.  0.5 3.5 0. ]

# %% [markdown]
# # Checking Unique values and Distribution plots of columns have big number values

# %%
# prints unique values and types of the columns
cols = ['number_of_reviews', 'days_since_last_review', 'days_since_first_review','host_days_since']
for col in cols:
    print(f"{col} | Type: {df[col].dtype} | Nulls: {df[col].isnull().sum()} | Filled: {df[col].notnull().sum

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.histplot(df[col], kde=True, bins=30, color='skyblue', edgecolor='black')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    
    plt.tight_layout()
    plt.show()
# Out:
# Column 'number_of_reviews' unique values: [  2   6  10   0   4   3  15   9 159  82]
# Column 'days_since_last_review' unique values: [3375 2943 2952 3091 3187 2961 3098 3107 2942 3103]
# Column 'days_since_first_review' unique values: [3405 2992 3089 3429 3808 2970 3140 3224 3531 3116]
# Column 'host_days_since' unique values: [4950 3039 3276 3831 3880 3051 3147 4532 3785 3138]

# %% [markdown]
# # As these four columns have high values, we can use a logarithmic transformation to lessen the effect of big numbers and reduce skewness.

# %%
cols = ['number_of_reviews', 'days_since_last_review', 'days_since_first_review','host_days_since']
for col in cols:
    df[col] = np.log1p(df[col])

# %% [markdown]
# ## Distribution and BoxPlot after applying logirithmic tranformation

# %%
cols = ['number_of_reviews', 'days_since_last_review', 'days_since_first_review','host_days_since']
for col in cols:
    print(f"Column '{col}' unique values:", df[col].unique()[:10])
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.histplot(df[col], kde=True, bins=30, color='skyblue', edgecolor='black')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    
    plt.tight_layout()
    plt.show()
# Out:
# Column 'number_of_reviews' unique values: [1.09861229 1.94591015 2.39789527 0.         1.60943791 1.38629436
#  2.77258872 2.30258509 5.07517382 4.41884061]
# Column 'days_since_last_review' unique values: [8.12444686 7.98752448 7.99057688 8.03657341 8.06714904 7.99361999
#  8.03883476 8.04173471 7.98718475 8.04044688]
# Column 'days_since_first_review' unique values: [8.13329386 8.00403151 8.03592637 8.14031554 8.24512197 7.99665388
#  8.0522965  8.07868823 8.16961956 8.04462628]
# Column 'host_days_since' unique values: [8.50734486 8.01961279 8.09468365 8.25114214 8.26384813 8.02355239
#  8.05452261 8.41913925 8.23906533 8.05165956]

# %% [markdown]
# # A few columns are of float datatype, but they can be converted to int since they don’t contain any decimal values.

# %%
print(df['review_scores_rating'].unique())
print(df['accommodates'].unique())
print(df['beds'].unique())
df['beds'] = df['beds'].astype(int)
df['accommodates'] = df['accommodates'].astype(int)
df['review_scores_rating'] = df['review_scores_rating'].astype(int)
# Out:
# [100.  93.  92.  96.  40.  97.  99.  90.  89.  91.  88.  86.  72.  98.
#   95.  84.  80.  94.  87.  85.  70.  60.  75.  20.  76.  83.  82.  78.
#   73.  55.  81.  67.  71.  77.  79.  47.  74.  68.  66.  63.  50.  53.
#   65.  64.  27.  69.  30.  58.  35.  62.  49.  57.  54.  56.]
# [ 3  7  5  4  2  6  8  1  9 10 16 11 12 14 13 15]
# [1 3 2 6 4 5 0]

# %% [markdown]
# log_price                 :   2.07% outliers
# accommodates              :   4.86% outliers done
# bathrooms                 :  21.34% outliers done
# host_has_profile_pic      :   0.30% outliers
# host_identity_verified    :   0.00% outliers
# host_response_rate        :  16.94% outliers done
# latitude                  :   0.00% outliers
# longitude                 :   0.00% outliers
# number_of_reviews         :  11.07% outliers done
# review_scores_rating      :   6.24% outliers
# zipcode                   :   0.00% outliers
# bedrooms                  :  32.70% outliers done
# beds                      :   7.67% outliers done
# amenities_count           :   1.84% outliers
# host_days_since           :   0.25% outliers done
# days_since_first_review   :   7.40% outliers done
# days_since_last_review    :  10.84% outliers done

# %% [markdown]
# # Heatmap to see correlation which column effect most the target variable

# %%
cols = df.columns.tolist()
print("cols_name:", cols)
# Out:
# cols_name: ['log_price', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy', 'cleaning_fee', 'city', 'host_has_profile_pic', 'host_identity_verified', 'host_response_rate', 'instant_bookable', 'latitude', 'longitude', 'neighbourhood', 'number_of_reviews', 'review_scores_rating', 'zipcode', 'bedrooms', 'beds', 'amenities_count', 'host_days_since', 'days_since_first_review', 'days_since_last_review']

# %%
num_cols = [
    'log_price','bathrooms','bedrooms', 'accommodates','beds','amenities_count','number_of_reviews',
    'review_scores_rating','host_response_rate','host_days_since','days_since_last_review']

corr = df[num_cols].corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %% [markdown]
# # 'Accommodates' has the strongest correlation with 'log_price' (0.57), meaning that as the number of accommodates increases, the price also tends to increase at a moderate level.
#
# # Beds and Bedrooms have moderate correlations with 'log_price' (0.47), indicating that they also increase with price but have less impact than 'Accommodates'.
#
# # The remaining columns are not highly correlated with 'log_price'.

# %%
cols = df.columns.tolist()
print("cols_name:", cols)
print("--"*50)
for col in cols:
    print(f"{col} | Type: {df[col].dtype} | Nulls: {df[col].isnull().sum()} | Filled: {df[col].notnull().sum()} | Unique Count: {df[col].nunique()}")
    print("Unique Values:", df[col].unique()[:100])
    print("-" * 80)
# Out:
# cols_name: ['log_price', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy', 'cleaning_fee', 'city', 'host_has_profile_pic', 'host_identity_verified', 'host_response_rate', 'instant_bookable', 'latitude', 'longitude', 'neighbourhood', 'number_of_reviews', 'review_scores_rating', 'zipcode', 'bedrooms', 'beds', 'amenities_count', 'host_days_since', 'days_since_first_review', 'days_since_last_review']
# ----------------------------------------------------------------------------------------------------
# log_price | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 767
# Unique Values: [5.01063529 5.12989872 4.97673374 6.62007321 4.74493213 4.44265126
#  4.41884061 4.78749174 3.58351894 4.60517019 4.24849524 5.29831737
#  4.95582706 4.09434456 4.31748811 4.59511985 4.88280192 4.38202663
#  3.68887945 4.90527478 4.00733319 6.95654544 5.00394631 4.55387689
#  5.19295685 4.65396035 3.8286414  5.22035583 4.48863637 4.35670883
#  4.82831374 3.912023   4.68213123 5.52146092 4.99721227 5.78382518
#  3.55534806 4.15888308 4.75359019 4.77912349 4.94875989 5.85793315
#  6.90775528 6.2146081  4.70048037 4.49980967 5.5174529  4.69134788
#  3.80666249 5.16478597 5.24702407 4.57471098 4.8598124  5.08759633
#  3.87120101 5.56068163 5.39362755 4.80402104 4.92725369 4.17438727
#  6.1717006  6.55108033 5.29330482 4.06044301 5.6347896  6.10924758
#  5.9375362  4.86753445 5.0689042  4.12713438 4.46590812 3.4657359
#  4.96284463 5.59842196 3.49650756 3.40119738 5.6167711  4.93447393
#  3.8918203  7.15070146 6.74523635 4.34380542 6.52795792 5.54126354
#  5.08140437 2.94443898 4.39444916 5.5759491  4.8978398  5.48063892
#  4.2195077  3.66356165 5.69709349 4.94164242 5.27299956 5.433722
#  4.58496748 4.18965474 5.99146455 6.26149168]
# --------------------------------------------------------------------------------
# property_type | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 35
# Unique Values: ['Apartment' 'House' 'Condominium' 'Loft' 'Townhouse' 'Hostel'
#  'Guest suite' 'Bed & Breakfast' 'Bungalow' 'Guesthouse' 'Dorm' 'Other'
#  'Camper/RV' 'Villa' 'Boutique hotel' 'Timeshare' 'In-law' 'Boat'
#  'Serviced apartment' 'Castle' 'Cabin' 'Treehouse' 'Tipi' 'Vacation home'
#  'Tent' 'Hut' 'Casa particular' 'Chalet' 'Yurt' 'Earth House'
#  'Parking Space' 'Train' 'Cave' 'Lighthouse' 'Island']
# --------------------------------------------------------------------------------
# room_type | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 3
# Unique Values: ['Entire home/apt' 'Private room' 'Shared room']
# --------------------------------------------------------------------------------
# accommodates | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count:
Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 73973
# Unique Values: [ -73.99161685  -73.98903992  -73.94375584 -122.4316187   -77.03459552
#  -122.4295261  -118.4628207  -118.2604389  -122.5010952  -117.8959966
#   -73.98388043 -118.4032926  -118.3894336   -77.03118943 -118.1459258
#   -87.69524167  -87.67526102  -71.04967213  -73.99028485  -73.95085466
#  -118.444462    -73.92264546 -118.2673519  -118.4309043   -77.03727241
#   -73.74546375 -118.3642036   -73.85154204 -118.2429231   -73.98082764
#   -73.94866663 -118.3459102  -118.4720329  -118.3647783  -118.2712267
#   -73.91351348 -122.4631288   -73.94520044  -73.98609197  -71.0531478
#   -87.61930317 -118.3200675  -118.2752044  -118.3567757  -118.4495962
#   -73.95377173  -77.05230862  -73.99099987  -73.9192194   -73.90856545
#   -87.67941891  -74.00425526 -122.4486087  -118.4565176   -73.96072628
#   -73.94120417  -73.99787332  -73.9997621   -73.9433389  -118.4519074
#   -71.05291817 -118.145861   -122.4029728   -76.97799439  -73.99628925
#  -118.2836444   -73.99834523 -118.3760293  -118.3133146  -118.3041888
#   -77.02530769  -73.96262541 -118.2821212   -73.95560803 -118.3459506
#  -118.2512598   -73.97752826 -118.0211027   -73.96311552  -73.95670408
#   -74.00242068  -73.92263996  -73.94019457 -122.4235098  -122.4075767
#  -118.3045588   -73.95056974 -118.3865229  -118.267016    -73.94216841
#   -76.93555537  -87.69941591  -73.95182313  -73.94643149  -77.02163619
#   -76.9492231   -73.97707905 -118.2807146   -73.9630543   -74.00660749]
# --------------------------------------------------------------------------------
# neighbourhood | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 620
# Unique Values: ['Brooklyn Heights' "Hell's Kitchen" 'Harlem' 'Lower Haight'
#  'Columbia Heights' 'Noe Valley' 'Unknown' 'Downtown' 'Richmond District'
#  'Alphabet City' 'Hermosa Beach' 'Torrance' 'U Street Corridor'
#  'Humboldt Park' 'Wicker Park' 'South Boston' 'Lower East Side' 'Flatbush'
#  'Sherman Oaks' 'East Flatbush' 'Valley Glen' 'Dupont Circle' 'Jamaica'
#  'Forest Hills' 'Murray Hill' 'Lefferts Garden' 'Mid-Wilshire' 'Venice'
#  'West Hollywood' 'Brownsville' 'Williamsburg' 'East Village'
#  'South Loop/Printers Row' 'Westlake' 'Hollywood Hills' 'Upper East Side'
#  'Bushwick' 'Bedford-Stuyvesant' 'Pilsen' 'Chelsea' 'Sunnyside'
#  'Greenwich Village' 'Washington Heights' 'Pasadena' 'Potrero Hill'
#  'Brookland' 'Los Feliz' 'Hollywood' 'Midtown East' 'Glendale'
#  'Park Slope' 'Arcadia' 'West Village' 'Astoria' 'Portola' 'Burbank'
#  'East Harlem' 'Silver Lake' 'Hillbrook' 'Shaw' 'Hillcrest'
#  'Morningside Heights' 'Tribeca' 'Studio City' 'Western Addition/NOPA'
#  'Echo Park' 'Financial District' 'Lakeview' 'Gramercy Park'
#  'Mission District' 'Kingman Park' 'Sunset Park' 'Upper West Side'
#  'Greenpoint' 'Highland Park' 'Cleveland Park' 'Prospect Heights'
#  'Glover Park' 'Gravesend' 'Jamaica Plain' 'Beacon Hill' 'SoMa' 'Flushing'
#  'Van Nuys' 'Del Rey' 'Midtown' 'Soho' 'Mission Hill' 'Roosevelt Island'
#  'Marina Del Rey' 'West Roxbury' 'Streeterville' 'Bernal Heights'
#  'Soundview' 'North Beach' 'Belmont Cragin' 'Crown Heights' 'Gowanus'
#  'Boerum Hill' 'Greenwood Heights']
# --------------------------------------------------------------------------------
# number_of_reviews | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count:
#  8.07340297 8.21851758 8.02027047 8.04942706 8.02224092 8.12207438
#  7.99496952 7.9868449  8.06085575 8.04494705 8.18060095 8.00101996
#  8.04430541 8.08641028 7.98548436 8.08671792 8.00369734 8.0730912
#  8.05452261 8.21581779 8.03527891 8.11252776 7.98922141 7.9983354
#  8.16990265 8.15478757 7.98854298 8.04654936 7.99429499 7.98480339
#  8.11552088 8.00603418 8.00135503 8.13211877 7.98616486 8.03818918
#  8.0836372  8.0955987  8.10530752 8.02059915 8.02715011 8.01433574
#  8.05896002 8.111328   8.00202482 8.12237124 7.99226864 8.00670085
#  8.02256895 8.01201824 8.09132127 8.19588539]
# --------------------------------------------------------------------------------

# %% [markdown]
# # Columns to encode using ordinat encode and replace value like t/f to 1/0 checking types of value in it

# %%
cols = ['cancellation_policy','instant_bookable','host_has_profile_pic','host_identity_verified','cleaning_fee']
print("cols_name:", cols)
print("--"*50)
for col in cols:
    print(f"{col} | Type: {df[col].dtype} | Nulls: {df[col].isnull().sum()} | Filled: {df[col].notnull().sum()} | Unique Count: {df[col].nunique()}")
    print("Unique Values:", df[col].unique()[:100])
    print("-" * 80)
# Out:
# cols_name: ['cancellation_policy', 'instant_bookable', 'host_has_profile_pic', 'host_identity_verified', 'cleaning_fee']
# ----------------------------------------------------------------------------------------------------
# cancellation_policy | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 5
# Unique Values: ['strict' 'moderate' 'flexible' 'super_strict_30' 'super_strict_60']
# --------------------------------------------------------------------------------
# instant_bookable | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 2
# Unique Values: ['f' 't']
# --------------------------------------------------------------------------------
# host_has_profile_pic | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 2
# Unique Values: [1. 0.]
# --------------------------------------------------------------------------------
# host_identity_verified | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 2
# Unique Values: [1. 0.]
# --------------------------------------------------------------------------------
# cleaning_fee | Type: bool | Nulls: 0 | Filled: 74111 | Unique Count: 2
# Unique Values: [ True False]
# --------------------------------------------------------------------------------

# %% [markdown]
# # Applying ordinal Encoding for cancellation_policy having natural order

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(categories=[['flexible', 'moderate', 'strict', 'super_strict_30', 'super_strict_60']])
df['cancellation_policy'] = encoder.fit_transform(df[['cancellation_policy']]).astype(int)

# %% [markdown]
# # convert category t/f, true/false, data to 1/0

# %%
df['instant_bookable'] = df['instant_bookable'].map({'t': 1, 'f': 0}).astype(int)
df['host_has_profile_pic'] = df['host_has_profile_pic'].astype(int)
df['host_identity_verified'] = df['host_identity_verified'].astype(int)
df['cleaning_fee'] = df['cleaning_fee'].astype(int)

# %%
cols = df.columns.tolist()
print("cols_name:", cols)
print("--"*50)
for col in cols:
    print(f"{col} | Type: {df[col].dtype} | Nulls: {df[col].isnull().sum()} | Filled: {df[col].notnull().sum()} | Unique Count: {df[col].nunique()}")
    print("Unique Values:", df[col].unique()[:10])
    print("-" * 80)
# Out:
# cols_name: ['log_price', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy', 'cleaning_fee', 'city', 'host_has_profile_pic', 'host_identity_verified', 'host_response_rate', 'instant_bookable', 'latitude', 'longitude', 'neighbourhood', 'number_of_reviews', 'review_scores_rating', 'zipcode', 'bedrooms', 'beds', 'amenities_count', 'host_days_since', 'days_since_first_review', 'days_since_last_review']
# ----------------------------------------------------------------------------------------------------
# log_price | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 767
# Unique Values: [5.01063529 5.12989872 4.97673374 6.62007321 4.74493213 4.44265126
#  4.41884061 4.78749174 3.58351894 4.60517019]
# --------------------------------------------------------------------------------
# property_type | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 35
# Unique Values: ['Apartment' 'House' 'Condominium' 'Loft' 'Townhouse' 'Hostel'
#  'Guest suite' 'Bed & Breakfast' 'Bungalow' 'Guesthouse']
# --------------------------------------------------------------------------------
# room_type | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 3
# Unique Values: ['Entire home/apt' 'Private room' 'Shared room']
# --------------------------------------------------------------------------------
# accommodates | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 16
# Unique Values: [ 3  7  5  4  2  6  8  1  9 10]
# --------------------------------------------------------------------------------
# bathrooms | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 8
# Unique Values: [1.  1.5 2.  2.5 3.  0.5 3.5 0. ]
# --------------------------------------------------------------------------------
# bed_type | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 5
# Unique Values: ['Real Bed' 'Futon' 'Pull-out Sofa' 'Couch' 'Airbed']
# --------------------------------------------------------------------------------
# cancellation_policy | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 5
# Unique Values: [2 1 0 3 4]
# --------------------------------------------------------------------------------
# cleaning_fee | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 2
# Unique Values: [1 0]
# --------------------------------------------------------------------------------
# city | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 6
# Unique Values: ['NYC' 'SF' 'DC' 'LA' 'Chicago' 'Boston']
# --------------------------------------------------------------------------------
# host_has_profile_pic | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 2
# Unique Values: [1 0]
# --------------------------------------------------------------------------------
# host_identity_verified | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 2
# Unique Values: [1 0]
# --------------------------------------------------------------------------------
# host_response_rate | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 80
# Unique Values: [100.  71.  68.  67.  83.  50.  90.  86.  92.  82.]
# --------------------------------------------------------------------------------
# instant_bookable | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 2
# Unique Values: [0 1]
# --------------------------------------------------------------------------------
# latitude | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 74058
# Unique Values: [40.69652363 40.76611542 40.80810999 37.77200448 38.92562692 37.75316405
#  33.9804544  34.04673741 37.78112798 33.99256298]
# --------------------------------------------------------------------------------
# longitude | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 73973
# Unique Values: [ -73.99161685  -73.98903992  -73.94375584 -122.4316187   -77.03459552
#  -122.4295261  -118.4628207  -118.2604389  -122.5010952  -117.8959966 ]
# --------------------------------------------------------------------------------
# neighbourhood | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 620
# Unique Values: ['Brooklyn Heights' "Hell's Kitchen" 'Harlem' 'Lower Haight'
#  'Columbia Heights' 'Noe Valley' 'Unknown' 'Downtown' 'Richmond District'
#  'Alphabet City']
# --------------------------------------------------------------------------------
# number_of_reviews | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 371
# Unique Values: [1.09861229 1.94591015 2.39789527 0.         1.60943791 1.38629436
#  2.77258872 2.30258509 5.07517382 4.41884061]
# --------------------------------------------------------------------------------
# review_scores_rating | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 54
# Unique Values: [100  93  92  96  40  97  99  90  89  91]
# --------------------------------------------------------------------------------
# zipcode | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 650
# Unique Values: [11201 10019 10027 94117 20009 94131 90292 90015 94121 91748]
# --------------------------------------------------------------------------------
# bedrooms | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 5
# Unique Values: [1 3 2 0 4]
# --------------------------------------------------------------------------------
# beds | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 7
# Unique Values: [1 3 2 6 4 5 0]
# --------------------------------------------------------------------------------
# amenities_count | Type: int64 | Nulls: 0 | Filled: 74111 | Unique Count: 73
# Unique Values: [ 8 14 18 15 12 10 21 26 22 17]
# --------------------------------------------------------------------------------
# host_days_since | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 3087
# Unique Values: [8.50734486 8.01961279 8.09468365 8.25114214 8.26384813 8.02355239
#  8.05452261 8.41913925 8.23906533 8.05165956]
# --------------------------------------------------------------------------------
# days_since_first_review | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 2554
# Unique Values: [8.13329386 8.00403151 8.03592637 8.14031554 8.24512197 7.99665388
#  8.0522965  8.07868823 8.16961956 8.04462628]
# --------------------------------------------------------------------------------
# days_since_last_review | Type: float64 | Nulls: 0 | Filled: 74111 | Unique Count: 1371
# Unique Values: [8.12444686 7.98752448 7.99057688 8.03657341 8.06714904 7.99361999
#  8.03883476 8.04173471 7.98718475 8.04044688]
# --------------------------------------------------------------------------------

# %% [markdown]
# # columns to one hot encode

# %%
cols = ['property_type','room_type','bed_type','city']
print("cols_name:", cols)
print("--"*50)
for col in cols:
    print(f"{col} | Type: {df[col].dtype} | Nulls: {df[col].isnull().sum()} | Filled: {df[col].notnull().sum()} | Unique Count: {df[col].nunique()}")
    print("Unique Values:", df[col].unique()[:10])
    print("-" * 80)
# Out:
# cols_name: ['property_type', 'room_type', 'bed_type', 'city']
# ----------------------------------------------------------------------------------------------------
# property_type | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 35
# Unique Values: ['Apartment' 'House' 'Condominium' 'Loft' 'Townhouse' 'Hostel'
#  'Guest suite' 'Bed & Breakfast' 'Bungalow' 'Guesthouse']
# --------------------------------------------------------------------------------
# room_type | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 3
# Unique Values: ['Entire home/apt' 'Private room' 'Shared room']
# --------------------------------------------------------------------------------
# bed_type | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 5
# Unique Values: ['Real Bed' 'Futon' 'Pull-out Sofa' 'Couch' 'Airbed']
# --------------------------------------------------------------------------------
# city | Type: object | Nulls: 0 | Filled: 74111 | Unique Count: 6
# Unique Values: ['NYC' 'SF' 'DC' 'LA' 'Chicago' 'Boston']
# --------------------------------------------------------------------------------

# %% [markdown]
# # Applying One-Hot Encode for nominal — no natural order, multiple categories.

# %%
from sklearn.preprocessing import OneHotEncoder
cols_to_encode = ['property_type','room_type','bed_type','city']

ohe = OneHotEncoder(drop='first', sparse_output=False)
encoded = ohe.fit_transform(df[cols_to_encode])
encoded_df = pd.DataFrame(encoded, columns=ohe.get_feature_names_out(cols_to_encode))
encoded_df.index = df.index

df = df.drop(cols_to_encode, axis=1).join(encoded_df)

# %% [markdown]
# # Target encoding for zipcode and neigborhood sicne they contains 600+ unique values
# # zipcode is nemeric but actually categorical data so it will be good for targeting encoding
#
# ## - Target encoding replaces categorical values with a numeric value that is derived from the target variable.
# ## - For regression usually it's the mean of the target for that particular category

# %%
for col in ['neighbourhood', 'zipcode']:
    target_mean = df.groupby(col)['log_price'].mean()
    df[col +'_encoded'] = df[col].map(target_mean)
    
    # Drop original column
    df.drop(col, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 66 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   log_price                         74111 non-null  float64
#  1   accommodates                      74111 non-null  int64
#  2   bathrooms                         74111 non-null  float64
#  3   cancellation_policy               74111 non-null  int64
#  4   cleaning_fee                      74111 non-null  int64
#  5   host_has_profile_pic              74111 non-null  int64
#  6   host_identity_verified            74111 non-null  int64
#  7   host_response_rate                74111 non-null  float64
#  8   instant_bookable                  74111 non-null  int64
#  9   latitude                          74111 non-null  float64
#  10  longitude                         74111 non-null  float64
#  11  number_of_reviews                 74111 non-null  float64
#  12  review_scores_rating              74111 non-null  int64
#  13  bedrooms                          74111 non-null  int64
#  14  beds                              74111 non-null  int64
#  15  amenities_count                   74111 non-null  int64
#  16  host_days_since                   74111 non-null  float64
#  17  days_since_first_review           74111 non-null  float64
#  18  days_since_last_review            74111 non-null  float64
#  19  property_type_Bed & Breakfast     74111 non-null  float64
#  20  property_type_Boat                74111 non-null  float64
#  21  property_type_Boutique hotel      74111 non-null  float64
#  22  property_type_Bungalow            74111 non-null  float64
#  23  property_type_Cabin               74111 non-null  float64
#  24  property_type_Camper/RV           74111 non-null  float64
#  25  property_type_Casa particular     74111 non-null  float64
#  26  property_type_Castle              74111 non-null  float64
#  27  property_type_Cave                74111 non-null  float64
#  28  property_type_Chalet              74111 non-null  float64
#  29  property_type_Condominium         74111 non-null  float64
#  30  property_type_Dorm                74111 non-null  float64
#  31  property_type_Earth House         74111 non-null  float64
#  32  property_type_Guest suite         74111 non-null  float64
#  33  property_type_Guesthouse          74111 non-null  float64
#  34  property_type_Hostel              74111 non-null  float64
#  35  property_type_House               74111 non-null  float64
#  36  property_type_Hut                 74111 non-null  float64
#  37  property_type_In-law              74111 non-null  float64
#  38  property_type_Island              74111 non-null  float64
#  39  property_type_Lighthouse          74111 non-null  float64
#  40  property_type_Loft                74111 non-null  float64
#  41  property_type_Other               74111 non-null  float64
#  42  property_type_Parking Space       74111 non-null  float64
#  43  property_type_Serviced apartment  74111 non-null  float64
#  44  property_type_Tent                74111 non-null  float64
#  45  property_type_Timeshare           74111 non-null  float64
#  46  property_type_Tipi                74111 non-null  float64
#  47  property_type_Townhouse           74111 non-null  float64
#  48  property_type_Train               74111 non-null  float64
#  49  property_type_Treehouse           74111 non-null  float64
#  50  property_type_Vacation home       74111 non-null  float64
#  51  property_type_Villa               74111 non-null  float64
#  52  property_type_Yurt                74111 non-null  float64
#  53  room_type_Private room            74111 non-null  float64
#  54  room_type_Shared room             74111 non-null  float64
#  55  bed_type_Couch                    74111 non-null  float64
#  56  bed_type_Futon                    74111 non-null  float64
#  57  bed_type_Pull-out Sofa            74111 non-null  float64
#  58  bed_type_Real Bed                 74111 non-null  float64
#  59  city_Chicago                      74111 non-null  float64
#  60  city_DC                           74111 non-null  float64
#  61  city_LA                           74111 non-null  float64
#  62  city_NYC                          74111 non-null  float64
#  63  city_SF                           74111 non-null  float64
#  64  neighbourhood_encoded             74111 non-null  float64
#  65  zipcode_encoded                   74111 non-null  float64
# dtypes: float64(56), int64(10)
# memory usage: 37.3 MB

# %% [markdown]
# # make variables for model train

# %%
x = df.drop(columns=['log_price'])
y = df['log_price']

# %% [markdown]
# # Standard Scaling for continuous numeric values columns

# %%
num_cols = ['latitude', 'longitude', 'review_scores_rating', 'amenities_count',
            'number_of_reviews', 'days_since_last_review',
            'host_response_rate', 'days_since_first_review',
            'host_days_since', 'beds', 'accommodates']

scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %% [markdown]
# # Data Splitting for training and test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Training the model and making prediction for test data to check accuracy of our data

# %%
my_lr = LinearRegression()
my_lr.fit(x_train, y_train)
y_pred = my_lr.predict(x_test)

# %%
errors = np.abs(y_test - y_pred)
colors = errors / errors.max() 

plt.figure(figsize=(8,6))
scatter = plt.scatter(y_test, y_pred, c=colors, cmap='viridis', alpha=0.8)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2) #draws perfet line linear regression
plt.xlabel('Actual log_price')
plt.ylabel('Predicted log_price')
plt.title('Linear Regression: Actual vs Predicted')
plt.colorbar(scatter, label='Normalized Error')
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Linear Regression Performance:")
print(f"MAE: {mae:.4f}")
print(f"R^2: {r2:.4f}")
# Out:
# Linear Regression Performance:
# MAE: 0.3003
# R^2: 0.6732

# %% [markdown]
# # Conclusion
# ## we get R^2 as 0.6734 means 67% of accurate prediction

# %% [markdown]
# # Now We will try another algorith that's XGBoost algorithm, which is robust to outliers because it is a tree-based method. It improves its accuracy each time a new tree is added, making the predictions progressively better.

# %% [markdown]
# ## Import xgboost (Extreme Gradient Boosting)

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # create model
# ### n_estimators: How many trees to be made
# ### max_depth: max depth of an each tree
# ### learning_rate: controls the step size for updating predictions from each tree
# ### subsample: how much data should be use for training the each tree
# ### colsample_bytree: the features each tree uses 0.8 as 80%

# %%
xgb_model = xgb.XGBRegressor(
    n_estimators=800,
    max_depth=7,
    learning_rate=0.05,
    subsample=0.75,
    colsample_bytree=0.75,
    random_state=42
)

# %% [markdown]
# ## Train the model

# %%
xgb_model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.75, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ## Make Prediction and evaluate the results

# %%
y_pred = xgb_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
rmse = mse**0.5
r2 = r2_score(y_test, y_pred)

print("RMSE:", rmse)
print("R^2 Score:", r2)
# Out:
# RMSE: 0.37024957015465987
# R^2 Score: 0.7331558627245942

# %% [markdown]
# ## Tree-based model gives R² = 0.73, higher than linear regression R² = 0.673.
# ## Trees are robust to outliers, so predictions are less affected by extreme values.
# ## Linear regression is sensitive to outliers, which can reduce its accuracy.
# ## Hence, tree model performs better on this dataset.

# %%
errors = np.abs(y_test - y_pred)
colors = errors / errors.max() 

plt.figure(figsize=(8,6))
scatter = plt.scatter(y_test, y_pred, c=colors, cmap='viridis', alpha=0.8)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual log_price')
plt.ylabel('Predicted log_price')
plt.title('Linear Regression: Actual vs Predicted')
plt.colorbar(scatter, label='Normalized Error')
plt.show()

# %% [markdown]
# # Testing multiple values to find best values for xgboost

# %%
n_estimators_list = [400, 500, 600]
max_depth_list = [4, 6, 8]
learning_rate_list = [0.01, 0.05, 0.1]
subsample_list = [0.7, 0.8, 1.0]
colsample_bytree_list = [0.7, 0.8, 1.0]

best_r2 = -1
best_params = {}

for n in n_estimators_list:
    for depth in max_depth_list:
        for lr in learning_rate_list:
            for subsample in subsample_list:
                for colsample in colsample_bytree_list:
                    model = xgb.XGBRegressor(
                        n_estimators=n,
                        max_depth=depth,
                        learning_rate=lr,
                        subsample=subsample,
                        colsample_bytree=colsample,
                        random_state=42
                    )
                    model.fit(x_train, y_train)
                    preds = model.predict(x_test)
                    r2 = r2_score(y_test, preds)
                    
                    if r2 > best_r2:
                        best_r2 = r2
                        best_params = {
                            'n_estimators': n,
                            'max_depth': depth,
                            'learning_rate': lr,
                            'subsample': subsample,
                            'colsample_bytree': colsample
                        }

print("Best R²:", best_r2)
print("Best Parameters:", best_params)
# Out:
# Best R²: 0.7328306146969199
# Best Parameters: {'n_estimators': 600, 'max_depth': 8, 'learning_rate': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.7}

# %%
n_estimators_list = [600, 700, 800]
max_depth_list = [5, 6, 7]
learning_rate_list = [0.03, 0.05, 0.07]
subsample_list = [0.75, 0.8, 0.85]
colsample_bytree_list = [0.75, 0.8, 0.85]

best_r2 = -1
best_params = {}

for n in n_estimators_list:
    for depth in max_depth_list:
        for lr in learning_rate_list:
            for subsample in subsample_list:
                for colsample in colsample_bytree_list:
                    model = xgb.XGBRegressor(
                        n_estimators=n,
                        max_depth=depth,
                        learning_rate=lr,
                        subsample=subsample,
                        colsample_bytree=colsample,
                        random_state=42
                    )
                    model.fit(x_train, y_train)
                    preds = model.predict(x_test)
                    r2 = r2_score(y_test, preds)
                    
                    if r2 > best_r2:
                        best_r2 = r2
                        best_params = {
                            'n_estimators': n,
                            'max_depth': depth,
                            'learning_rate': lr,
                            'subsample': subsample,
                            'colsample_bytree': colsample
                        }

print("Best R²:", best_r2)
print("Best Parameters:", best_params)
# Out:
# Best R²: 0.7331558627245942
# Best Parameters: {'n_estimators': 800, 'max_depth': 7, 'learning_rate': 0.05, 'subsample': 0.75, 'colsample_bytree': 0.75}
